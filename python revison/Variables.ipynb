# %% [markdown]
# ## Variables
# A variable is a container used to store data in memory.
#
# - Variables store data
# - Python does not require datatype declaration
# - Variable names should be meaningful
# - Avoid using spaces in variable names

# %%
## Question 1: Create a variable named `student_name` and store your name in it. Print the variable.

student_name = "Mohammed Taleeb Chouhan "
print(student_name)
# Out:
# Mohammed Taleeb Chouhan

# %%
## Question 2 : Create variables for your age, city, and favorite programming language. Print all variables.
age = 21
city = 'Sikar (Rajasthan)'
favorite_language = "Python"
print(f"{age},{city},{favorite_language}")
# Out:
# 21,Sikar (Rajasthan),Python

# %%
## Question 3 : Create Two variables 'a' and 'b' with numeric values. print their addition.
a = 21
b = 22
print(f"{a+b}")
# Out:
# 43

# %%
## Question 4 : Create a variable storing your mobile number and print it.

mobile = 9214913141
print(mobile)
# Out:
# 9214913141

# %%
## Question 5 : Create a variable `price` and print its datatype using `type()`.

price = 1200
print(type(price))
# Out:
# <class 'int'>

# %%
## Question 6 : Create variables `first_name` and `last_name`. Print your full name using both variables.

first_name = "Mohammed Taleeb"
last_name = "Chouhan"

print(f"{first_name} {last_name}")
# Out:
# Mohammed Taleeb Chouhan

# %%
## Question 7 : Create a variable `country` and change its value after printing it once. Then print the updated value.

country  = "India"
print(country)
country = "Dubai"
print(country)
# Out:
# India
# Dubai

# %%
## Question 8 : Create variables `length` and `width`. Calculate and print the area of a rectangle.

length = float(input("Enter length :"))
width = float(input("Enter width :"))

print(f"Area of reactangle : {length * width}")
# Out:
# Area of reactangle : 274.29

# %%
## Question 9 : create a variable storing your favorite number . print its square and cude.
Fav_number = int(input("enter your favorite number : "))

print(f"Sqare of your favorite number : {Fav_number * Fav_number}.")
print(f"Cube of your favorite number {Fav_number * Fav_number * Fav_number}.")
# Out:
# Sqare of your favorite number : 25.
# Cube of your favorite number 125.

# %%
## Question 10 : Create a boolean variable 'is_logged_in' . Print the variable and its datatype.

is_logged_in = True 
print(f"Boolean Variable : {is_logged_in}")
print(f"datatype : {type(is_logged_in)}")
# Out:
# Boolean Variable : True
# datatype : <class 'bool'>

# %%
## Question 11 : Create three variable in a single line and print all of them. 

a = "Taleeb"
b = 1910
c = True 
print(f"Three Variables : {a , b, c}")
# Out:
# Three Variables : ('Taleeb', 1910, True)

# %%
## Question 12 : swap the values of two variable without using a third varibale .
a = 10
b = 20
a , b = b ,a 
print("a =",a)
print("b =",b)
# Out:
# a = 20
# b = 10

# %%
## Question 13 : Create a variable storing a sentence. Print : -First character , -last character

sentences = "I am Taleeb"
print("First character :",sentences[0])
print("Last character :",sentences[-1])
# Out:
# First character : I
# Last character : b

# %%
## Question 15:Create variables for:- student name,- course,- marks,- city.Print all details in a proper formatted way.

Student_name = "Mohammed Taleeb"
course = "B.Tech"
marks = 100
city = "Sikar"

print(f"Name of Student :{Student_name}")
print(f"Course : {course}")
print(f"Marks of student : {marks}")
print(f"Student locality : {city}")
# Out:
# Name of Student :Mohammed Taleeb
# Course : B.Tech
# Marks of student : 100
# Student locality : Sikar
