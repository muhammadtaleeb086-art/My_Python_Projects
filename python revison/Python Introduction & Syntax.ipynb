# %% [markdown]
# # Python Introduction & Syntax
#  - Python is case-sensitive.
#  - Indentation matters in Python.
#  - print() is used to display output.
#  - (#) is used for comments.
#  - Python code should be clean and readable.

# %%
## Question 1: Write a Python program to print:Hello Python 
print("Hello Python")
# Out:
# Hello Python

# %%
## Question 2 : Write a Python program to print your:Name,Age,City  on separate lines.
print("Mohammed Taleeb Chouhan.")
print("I'm 21 year old.")
print("I'm Living in Sikar.")
# Out:
# Mohammed Taleeb Chouhan.
# I'm 21 year old.
# I'm Living in Sikar.

# %%
## Question 3 : Write a Python program using both:single quotes,double quotes inside print().
print('Hello world')
print("Hello world")
# Out:
# Hello world
# Hello world

# %%
## Question 4 : Write a Python comment:
## This is sigle line comment 
"""
this is used for 
multi line 
comment
"""

# %%
## Question 5 : Write a Python program to print:Welcome to Python
print("Welcome")
print("to")
print("Python")
# Out:
# Welcome
# to
# Python

# %%
# Question 6 : Fix the error in the following code: Print("Hello")
print("Hello") # Print ( Capital P is wrong)
# Out:
# Hello

# %%
# Question 7 :Fix the indentation error:
# if True:
# print("Python")

if True :
  print("Python")
# Out:
# Python

# %%
# Question 8 : Write a Python program that prints: Python is fun! using 3 different print() statements.
print("Python")
print("is")
print("Fun!")
# Out:
# Python
# is
# Fun!

# %%
# Question 9 : Write a program that prints a small pattern: 
# *
# **
# ***
# ****

print("*")
print("**")
print("***")
print("****")
print("*****")
# Out:
# *
# **
# ***
# ****
# *****

# %%
# Questipn 10 : Write a Python program using escape characters to print:
#  Hello
#  World
#  Python
# using a single print() statement.

print("Hello World Python")
# Out:
# Hello World Python
